# %%
import os
import torch
import polars as pl
import seaborn as sns
def get_parent_dir(directory):
    import os
    return os.path.dirname(directory)

current_dirs_parent = get_parent_dir(os.getcwd())
os.chdir(current_dirs_parent)

# %%
for i in range(torch.cuda.device_count()):
   print(torch.cuda.get_device_properties(i).name)
# Out:
# NVIDIA GeForce RTX 4090

# %%
cats_df = pl.read_csv("data/data.csv", separator=",")

# %%
cats_df.columns
# Out:
# ['timestamp',
#  'aimp',
#  'amud',
#  'arnd',
#  'asin1',
#  'asin2',
#  'adbr',
#  'adfl',
#  'bed1',
#  'bed2',
#  'bfo1',
#  'bfo2',
#  'bso1',
#  'bso2',
#  'bso3',
#  'ced1',
#  'cfo1',
#  'cso1',
#  'y',
#  'category']

# %%
cats_df.head()
# Out:
# shape: (5, 20)
# ┌─────────────────────┬──────┬──────┬───────────┬───┬──────────┬──────────┬─────┬──────────┐
# │ timestamp           ┆ aimp ┆ amud ┆ arnd      ┆ … ┆ cfo1     ┆ cso1     ┆ y   ┆ category │
# │ ---                 ┆ ---  ┆ ---  ┆ ---       ┆   ┆ ---      ┆ ---      ┆ --- ┆ ---      │
# │ str                 ┆ f64  ┆ f64  ┆ f64       ┆   ┆ f64      ┆ f64      ┆ f64 ┆ f64      │
# ╞═════════════════════╪══════╪══════╪═══════════╪═══╪══════════╪══════════╪═════╪══════════╡
# │ 2023-01-01 00:00:00 ┆ 0.0  ┆ 1.0  ┆ 20.0      ┆ … ┆ 0.0      ┆ 0.0      ┆ 0.0 ┆ 0.0      │
# │ 2023-01-01 00:00:01 ┆ 0.0  ┆ 1.0  ┆ 20.080031 ┆ … ┆ 0.000021 ┆ 0.001229 ┆ 0.0 ┆ 0.0      │
# │ 2023-01-01 00:00:02 ┆ 0.0  ┆ 1.0  ┆ 20.276562 ┆ … ┆ 0.000104 ┆ 0.004833 ┆ 0.0 ┆ 0.0      │
# │ 2023-01-01 00:00:03 ┆ 0.0  ┆ 1.0  ┆ 20.730938 ┆ … ┆ 0.000285 ┆ 0.010688 ┆ 0.0 ┆ 0.0      │
# │ 2023-01-01 00:00:04 ┆ 0.0  ┆ 1.0  ┆ 21.118101 ┆ … ┆ 0.000601 ┆ 0.018669 ┆ 0.0 ┆ 0.0      │
# ...

# %%
sns.kdeplot(data=cats_df, x="aimp")
# Out:
# <Axes: xlabel='aimp', ylabel='Density'>

# %%
sns.kdeplot(data=cats_df, x="amud")
# Out:
# <Axes: xlabel='amud', ylabel='Density'>

# %%
sns.kdeplot(data=cats_df, x="asin1")
# Out:
# <Axes: xlabel='asin1', ylabel='Density'>

# %%
sns.kdeplot(data=cats_df, x="asin2")
# Out:
# <Axes: xlabel='asin2', ylabel='Density'>

# %%
sns.kdeplot(data=cats_df, x="adbr")
# Out:
# <Axes: xlabel='adbr', ylabel='Density'>

# %%
sns.kdeplot(data=cats_df, x="adfl")
# Out:
# <Axes: xlabel='adfl', ylabel='Density'>

# %%
sns.kdeplot(data=cats_df, x="bed1")
# Out:
# <Axes: xlabel='bed1', ylabel='Density'>

# %%
sns.kdeplot(data=cats_df, x="bed2")
# Out:
# <Axes: xlabel='bed2', ylabel='Density'>

# %%
sns.kdeplot(data=cats_df, x="bfo1")
# Out:
# <Axes: xlabel='bfo1', ylabel='Density'>

# %%
sns.kdeplot(data=cats_df, x="bfo2")
# Out:
# <Axes: xlabel='bfo2', ylabel='Density'>

# %%
sns.kdeplot(data=cats_df, x="bso1")
# Out:
# <Axes: xlabel='bso1', ylabel='Density'>

# %%
sns.kdeplot(data=cats_df, x="bso2")
# Out:
# <Axes: xlabel='bso2', ylabel='Density'>

# %%
sns.kdeplot(data=cats_df, x="bso3")
# Out:
# <Axes: xlabel='bso3', ylabel='Density'>

# %%
sns.kdeplot(data=cats_df, x="ced1")
# Out:
# <Axes: xlabel='ced1', ylabel='Density'>

# %%
sns.kdeplot(data=cats_df, x="cfo1")
# Out:
# <Axes: xlabel='cfo1', ylabel='Density'>

# %%
sns.kdeplot(data=cats_df, x="cso1")
# Out:
# <Axes: xlabel='cso1', ylabel='Density'>

# %%
sns.kdeplot(data=cats_df, x="y")
# Out:
# <Axes: xlabel='y', ylabel='Density'>

# %%
metadata = pl.read_csv("data/metadata.csv", separator=",")

# %%
metadata.head()
# Out:
# shape: (5, 5)
# ┌─────────────────────┬─────────────────────┬────────────┬──────────┬──────────┐
# │ start_time          ┆ end_time            ┆ root_cause ┆ affected ┆ category │
# │ ---                 ┆ ---                 ┆ ---        ┆ ---      ┆ ---      │
# │ str                 ┆ str                 ┆ str        ┆ str      ┆ i64      │
# ╞═════════════════════╪═════════════════════╪════════════╪══════════╪══════════╡
# │ 2023-01-12 15:11:45 ┆ 2023-01-12 15:20:05 ┆ bso3       ┆ ['cfo1'] ┆ 12       │
# │ 2023-01-12 16:27:46 ┆ 2023-01-12 17:51:06 ┆ bso3       ┆ ['cfo1'] ┆ 1        │
# │ 2023-01-12 18:19:35 ┆ 2023-01-12 18:36:15 ┆ bfo2       ┆ ['cso1'] ┆ 8        │
# │ 2023-01-12 20:46:32 ┆ 2023-01-12 20:51:32 ┆ bed2       ┆ ['ced1'] ┆ 7        │
# │ 2023-01-13 05:57:10 ┆ 2023-01-13 06:02:10 ┆ bfo1       ┆ ['cfo1'] ┆ 9        │
# └─────────────────────┴─────────────────────┴────────────┴──────────┴──────────┘

# %%
metadata.unique(subset=["root_cause"], maintain_order=True)
# Out:
# shape: (7, 5)
# ┌─────────────────────┬─────────────────────┬────────────┬──────────┬──────────┐
# │ start_time          ┆ end_time            ┆ root_cause ┆ affected ┆ category │
# │ ---                 ┆ ---                 ┆ ---        ┆ ---      ┆ ---      │
# │ str                 ┆ str                 ┆ str        ┆ str      ┆ i64      │
# ╞═════════════════════╪═════════════════════╪════════════╪══════════╪══════════╡
# │ 2023-01-12 15:11:45 ┆ 2023-01-12 15:20:05 ┆ bso3       ┆ ['cfo1'] ┆ 12       │
# │ 2023-01-12 18:19:35 ┆ 2023-01-12 18:36:15 ┆ bfo2       ┆ ['cso1'] ┆ 8        │
# │ 2023-01-12 20:46:32 ┆ 2023-01-12 20:51:32 ┆ bed2       ┆ ['ced1'] ┆ 7        │
# │ 2023-01-13 05:57:10 ┆ 2023-01-13 06:02:10 ┆ bfo1       ┆ ['cfo1'] ┆ 9        │
# │ 2023-01-13 10:33:15 ┆ 2023-01-13 10:44:55 ┆ bso1       ┆ ['cfo1'] ┆ 4        │
# │ 2023-01-14 01:14:42 ┆ 2023-01-14 01:26:22 ┆ bso2       ┆ ['cso1'] ┆ 5        │
# ...

# %%
metadata.unique(subset=["affected"], maintain_order=True)
# Out:
# shape: (3, 5)
# ┌─────────────────────┬─────────────────────┬────────────┬──────────┬──────────┐
# │ start_time          ┆ end_time            ┆ root_cause ┆ affected ┆ category │
# │ ---                 ┆ ---                 ┆ ---        ┆ ---      ┆ ---      │
# │ str                 ┆ str                 ┆ str        ┆ str      ┆ i64      │
# ╞═════════════════════╪═════════════════════╪════════════╪══════════╪══════════╡
# │ 2023-01-12 15:11:45 ┆ 2023-01-12 15:20:05 ┆ bso3       ┆ ['cfo1'] ┆ 12       │
# │ 2023-01-12 18:19:35 ┆ 2023-01-12 18:36:15 ┆ bfo2       ┆ ['cso1'] ┆ 8        │
# │ 2023-01-12 20:46:32 ┆ 2023-01-12 20:51:32 ┆ bed2       ┆ ['ced1'] ┆ 7        │
# └─────────────────────┴─────────────────────┴────────────┴──────────┴──────────┘

# %%
cats_df.unique(subset=["category"], maintain_order=True)
# Out:
# shape: (14, 20)
# ┌─────────────────────┬──────┬───────┬───────────┬───┬────────────┬───────────┬─────┬──────────┐
# │ timestamp           ┆ aimp ┆ amud  ┆ arnd      ┆ … ┆ cfo1       ┆ cso1      ┆ y   ┆ category │
# │ ---                 ┆ ---  ┆ ---   ┆ ---       ┆   ┆ ---        ┆ ---       ┆ --- ┆ ---      │
# │ str                 ┆ f64  ┆ f64   ┆ f64       ┆   ┆ f64        ┆ f64       ┆ f64 ┆ f64      │
# ╞═════════════════════╪══════╪═══════╪═══════════╪═══╪════════════╪═══════════╪═════╪══════════╡
# │ 2023-01-01 00:00:00 ┆ 0.0  ┆ 1.0   ┆ 20.0      ┆ … ┆ 0.0        ┆ 0.0       ┆ 0.0 ┆ 0.0      │
# │ 2023-01-12 15:11:45 ┆ 0.0  ┆ -13.0 ┆ 18.849854 ┆ … ┆ -19.143357 ┆ 46.921675 ┆ 1.0 ┆ 12.0     │
# │ 2023-01-12 16:27:46 ┆ 0.0  ┆ -4.0  ┆ 14.092162 ┆ … ┆ -1.417773  ┆ 43.987272 ┆ 1.0 ┆ 1.0      │
# │ 2023-01-12 18:19:35 ┆ 0.0  ┆ 3.0   ┆ 10.708922 ┆ … ┆ 6.353298   ┆ 48.90461  ┆ 1.0 ┆ 8.0      │
# ...

# %%
cats_df.columns
# Out:
# ['timestamp',
#  'aimp',
#  'amud',
#  'arnd',
#  'asin1',
#  'asin2',
#  'adbr',
#  'adfl',
#  'bed1',
#  'bed2',
#  'bfo1',
#  'bfo2',
#  'bso1',
#  'bso2',
#  'bso3',
#  'ced1',
#  'cfo1',
#  'cso1',
#  'y',
#  'category']

# %%
cats_df.head
# Out:
# <bound method DataFrame.head of shape: (5_000_000, 20)
# ┌─────────────────────┬──────┬───────┬───────────┬───┬────────────┬───────────┬─────┬──────────┐
# │ timestamp           ┆ aimp ┆ amud  ┆ arnd      ┆ … ┆ cfo1       ┆ cso1      ┆ y   ┆ category │
# │ ---                 ┆ ---  ┆ ---   ┆ ---       ┆   ┆ ---        ┆ ---       ┆ --- ┆ ---      │
# │ str                 ┆ f64  ┆ f64   ┆ f64       ┆   ┆ f64        ┆ f64       ┆ f64 ┆ f64      │
# ╞═════════════════════╪══════╪═══════╪═══════════╪═══╪════════════╪═══════════╪═════╪══════════╡
# │ 2023-01-01 00:00:00 ┆ 0.0  ┆ 1.0   ┆ 20.0      ┆ … ┆ 0.0        ┆ 0.0       ┆ 0.0 ┆ 0.0      │
# │ 2023-01-01 00:00:01 ┆ 0.0  ┆ 1.0   ┆ 20.080031 ┆ … ┆ 0.000021   ┆ 0.001229  ┆ 0.0 ┆ 0.0      │
# │ 2023-01-01 00:00:02 ┆ 0.0  ┆ 1.0   ┆ 20.276562 ┆ … ┆ 0.000104   ┆ 0.004833  ┆ 0.0 ┆ 0.0      │
# │ 2023-01-01 00:00:03 ┆ 0.0  ┆ 1.0   ┆ 20.730938 ┆ … ┆ 0.000285   ┆ 0.010688  ┆ 0.0 ┆ 0.0      │
# ...

# %%
test = cats_df.filter(pl.col('category')==12)

# %%
test.head()
# Out:
# shape: (5, 20)
# ┌─────────────────────┬──────┬───────┬───────────┬───┬────────────┬───────────┬─────┬──────────┐
# │ timestamp           ┆ aimp ┆ amud  ┆ arnd      ┆ … ┆ cfo1       ┆ cso1      ┆ y   ┆ category │
# │ ---                 ┆ ---  ┆ ---   ┆ ---       ┆   ┆ ---        ┆ ---       ┆ --- ┆ ---      │
# │ str                 ┆ f64  ┆ f64   ┆ f64       ┆   ┆ f64        ┆ f64       ┆ f64 ┆ f64      │
# ╞═════════════════════╪══════╪═══════╪═══════════╪═══╪════════════╪═══════════╪═════╪══════════╡
# │ 2023-01-12 15:11:45 ┆ 0.0  ┆ -13.0 ┆ 18.849854 ┆ … ┆ -19.143357 ┆ 46.921675 ┆ 1.0 ┆ 12.0     │
# │ 2023-01-12 15:11:46 ┆ 0.0  ┆ -13.0 ┆ 19.01898  ┆ … ┆ -19.02474  ┆ 46.906484 ┆ 1.0 ┆ 12.0     │
# │ 2023-01-12 15:11:47 ┆ 0.0  ┆ -13.0 ┆ 18.538839 ┆ … ┆ -18.906694 ┆ 46.8876   ┆ 1.0 ┆ 12.0     │
# │ 2023-01-12 15:11:48 ┆ 0.0  ┆ -13.0 ┆ 18.563336 ┆ … ┆ -18.789267 ┆ 46.864738 ┆ 1.0 ┆ 12.0     │
# ...

# %%
test.unique(subset=["y"], maintain_order=True)
# Out:
# shape: (1, 20)
# ┌─────────────────────┬──────┬───────┬───────────┬───┬────────────┬───────────┬─────┬──────────┐
# │ timestamp           ┆ aimp ┆ amud  ┆ arnd      ┆ … ┆ cfo1       ┆ cso1      ┆ y   ┆ category │
# │ ---                 ┆ ---  ┆ ---   ┆ ---       ┆   ┆ ---        ┆ ---       ┆ --- ┆ ---      │
# │ str                 ┆ f64  ┆ f64   ┆ f64       ┆   ┆ f64        ┆ f64       ┆ f64 ┆ f64      │
# ╞═════════════════════╪══════╪═══════╪═══════════╪═══╪════════════╪═══════════╪═════╪══════════╡
# │ 2023-01-12 15:11:45 ┆ 0.0  ┆ -13.0 ┆ 18.849854 ┆ … ┆ -19.143357 ┆ 46.921675 ┆ 1.0 ┆ 12.0     │
# └─────────────────────┴──────┴───────┴───────────┴───┴────────────┴───────────┴─────┴──────────┘
